# %% [markdown]
# ## Cleaning Marketing Campaign Messy Data
# The Dataset is Messy. Column names have

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('marketing_campaign_data_messy.csv')
df.head()
# Out:
#    Campaign_ID              Campaign_Name           Start_Date    End_Date  \
# 0     CMP-00001       Q4_Summer_CMP-00001  2023-11-24 00:00:00  2023-12-13
# 1     CMP-00002       Q1_Launch_CMP-00002  2023-05-06 00:00:00  2023-05-12
# 2     CMP-00003       Q3_Winter_CMP-00003  2023-12-13 00:00:00  2023-12-20
# 3     CMP-00004  Q1_BlackFriday_CMP-00004           2023-10-30  2023-11-03
# 4     CMP-00005       Q2_Winter_CMP-00005  2023-04-22 00:00:00  2023-04-23
#
#     Channel  Impressions  Clicks     Spend  Conversions Active  Clicks  \
# 0    TikTok        16795      197  $102.82         20.0      Y     NaN
# 1  Facebook         1860       30    24.33          1.0      0     NaN
# 2     Email        77820      843  1323.39         51.0     No     NaN
# 3    TikTok        55886     2019  2180.38        135.0   True     NaN
# 4  Facebook         7265      169   252.44         30.0    Yes     NaN
#
#   Campaign_Tag
# 0           TI
# 1           FA
# 2           EM
# 3           TI
# 4           FA

# %% [markdown]
# ## Cleaning Header
#
# Header have blank spaces, that can make it harder to call, So I will remove the spaces, and also convert column header in Lower Case

# %%
print(df.columns.tolist())
# Out:
# [' Campaign_ID ', 'Campaign_Name', 'Start_Date', 'End_Date', 'Channel', 'Impressions', 'Clicks ', 'Spend', 'Conversions', 'Active', 'Clicks', 'Campaign_Tag']

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')
print(df.columns.tolist())
# Out:
# ['campaign_id', 'campaign_name', 'start_date', 'end_date', 'channel', 'impressions', 'clicks', 'spend', 'conversions', 'active', 'clicks', 'campaign_tag']

# %% [markdown]
# ## Type and Currency Cleaning

# %%
df[df['spend'].astype(str).str.contains(r'\$')].head()
# Out:
#    campaign_id             campaign_name           start_date    end_date  \
# 0    CMP-00001       Q4_Summer_CMP-00001  2023-11-24 00:00:00  2023-12-13
# 21   CMP-00022  Q2_BlackFriday_CMP-00022  2023-12-26 00:00:00  2024-01-02
# 22   CMP-00023       Q4_Winter_CMP-00023  2023-11-08 00:00:00  2023-11-24
# 31   CMP-00032       Q2_Summer_CMP-00032  2023-05-07 00:00:00  2023-05-29
# 32   CMP-00033  Q2_BlackFriday_CMP-00033  2023-10-27 00:00:00  2023-10-29
#
#        channel  impressions  clicks     spend  conversions active   clicks  \
# 0       TikTok        16795     197   $102.82         20.0      Y      NaN
# 21  Google Ads        54707    1735   $2428.4          NaN      Y      NaN
# 22  Google Ads        86305    2637  $4726.22        216.0      0  86385.0
# 31   Instagram        66725    1424  $2759.35        251.0   True      NaN
# 32   Instagram        85654    2087  $2393.02        122.0      0      NaN
#
#    campaign_tag
# 0            TI
# 21           GO
# 22           GO
# 31           IN
# 32           IN

# %%
# Remove dollar signs and convert 'spend' to numeric
df['spend'] = df['spend'].astype(str).str.replace(r'[^\d.-]', '', regex=True)
df['spend'] = pd.to_numeric(df['spend'])

# %% [markdown]
# ## Categorical Typos (Fuzzy Logic)

# %%
df['channel'].value_counts()
# Out:
# channel
# TikTok        399
# Facebook      391
# Email         359
# Google Ads    346
# Instagram     340
# E-mail         21
# Insta_gram     19
# Tik_Tok        16
# Gogle          14
# Facebok        14
# Name: count, dtype: int64

# %%
clean_up = {'Facebok' : 'Facebook',
    'Insta_gram' : 'Instagram',
    'Gogle' : 'Google',
    'Tik_Tok' : 'TikTok',
    'E-mail' : 'Email',
    'N/A' : np.nan}

df['channel'] = df['channel'].replace(clean_up)

# %%
df['channel'].unique()
# Out:
# array(['TikTok', 'Facebook', 'Email', 'Instagram', 'Google Ads', nan,
#        'Google'], dtype=object)

# %% [markdown]
# ## Handling Mixed Booleans

# %%
df['active'].value_counts()
# Out:
# active
# 1        319
# Yes      306
# True     297
# No       291
# False    281
# Y        273
# 0        253
# Name: count, dtype: int64

# %%
bool_map = {'Yes' : True,
            'No' : False,
            'Y' : True,
            '0' : False,
            1 : True,
            0 : False,
            '1' : True,
            'True' : True,
            'False' : False}

df['active'] = df['active'].replace(bool_map).fillna(False).astype(bool)
# Out:
# /var/folders/z8/nbvk5kgd18g2blb0t3nbxnmm0000gn/T/ipykernel_56246/4289463038.py:11: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['active'] = df['active'].replace(bool_map).fillna(False).astype(bool)

# %%
df['active'].value_counts()
# Out:
# active
# True     1195
# False     825
# Name: count, dtype: int64

# %% [markdown]
# ## Parsing Date
#
# How Start and End Date are completely different and badly formatted.

# %%
df.head()
# Out:
#   campaign_id             campaign_name           start_date    end_date  \
# 0   CMP-00001       Q4_Summer_CMP-00001  2023-11-24 00:00:00  2023-12-13
# 1   CMP-00002       Q1_Launch_CMP-00002  2023-05-06 00:00:00  2023-05-12
# 2   CMP-00003       Q3_Winter_CMP-00003  2023-12-13 00:00:00  2023-12-20
# 3   CMP-00004  Q1_BlackFriday_CMP-00004           2023-10-30  2023-11-03
# 4   CMP-00005       Q2_Winter_CMP-00005  2023-04-22 00:00:00  2023-04-23
#
#     channel  impressions  clicks    spend  conversions  active  clicks  \
# 0    TikTok        16795     197   102.82         20.0    True     NaN
# 1  Facebook         1860      30    24.33          1.0   False     NaN
# 2     Email        77820     843  1323.39         51.0   False     NaN
# 3    TikTok        55886    2019  2180.38        135.0    True     NaN
# 4  Facebook         7265     169   252.44         30.0    True     NaN
#
#   campaign_tag
# 0           TI
# 1           FA
# 2           EM
# 3           TI
# 4           FA

# %%
print(df['start_date'].dtype)

#Object means data is stored as strings
# Out:
# object

# %%
df['start_date'] = pd.to_datetime(df['start_date'], errors='coerce')
df['end_date'] = pd.to_datetime(df['end_date'], errors='coerce')
df
# Out:
#      campaign_id             campaign_name start_date   end_date     channel  \
# 0      CMP-00001       Q4_Summer_CMP-00001 2023-11-24 2023-12-13      TikTok
# 1      CMP-00002       Q1_Launch_CMP-00002 2023-05-06 2023-05-12    Facebook
# 2      CMP-00003       Q3_Winter_CMP-00003 2023-12-13 2023-12-20       Email
# 3      CMP-00004  Q1_BlackFriday_CMP-00004        NaT 2023-11-03      TikTok
# 4      CMP-00005       Q2_Winter_CMP-00005 2023-04-22 2023-04-23    Facebook
# ...          ...                       ...        ...        ...         ...
# 2015   CMP-00400       Q3_Summer_CMP-00400 2023-10-31 2023-11-13      TikTok
# 2016   CMP-01255       Q4_Summer_CMP-01255 2023-09-01 2023-09-26  Google Ads
# 2017   CMP-01050       Q2_Launch_CMP-01050 2023-02-09 2023-02-21   Instagram
# 2018   CMP-01118       Q4_Winter_CMP-01118 2023-03-30 2023-04-27    Facebook
# 2019   CMP-01554       Q4_Launch_CMP-01554 2023-06-26 2023-07-09       Email
#
#       impressions  clicks    spend  conversions  active  clicks campaign_tag
# 0           16795     197   102.82         20.0    True     NaN           TI
# 1            1860      30    24.33          1.0   False     NaN           FA
# 2           77820     843  1323.39         51.0   False     NaN           EM
# 3           55886    2019  2180.38        135.0    True     NaN           TI
# 4            7265     169   252.44         30.0    True     NaN           FA
# ...           ...     ...      ...          ...     ...     ...          ...
# 2015        30592     586   503.95         77.0    True     NaN           TI
# 2016        20097     897  1641.00        162.0   False     NaN           GO
# 2017        33254    1117   883.82        214.0   False     NaN           IN
# 2018        68728    2960  4198.50        591.0    True     NaN           FA
# 2019        96402    1090  1315.59         66.0    True     NaN           EM
#
# [2020 rows x 12 columns]

# %% [markdown]
# ## Logical Error (More Clicks than Impressions)

# %%
#Turns out there are two dupilicate columns named 'clicks'
df = df.loc[:, ~df.columns.duplicated()]

# %%
df.query('clicks > impressions')
# Out:
# Empty DataFrame
# Columns: [campaign_id, campaign_name, start_date, end_date, channel, impressions, clicks, spend, conversions, active, campaign_tag]
# Index: []

# %% [markdown]
# ## Logical Integrity (Start time cannot be before End Time)

# %%
df.loc[df['start_date'] > df['end_date']].head(3)
# Out:
#    campaign_id        campaign_name start_date   end_date     channel  \
# 23   CMP-00024  Q4_Winter_CMP-00024 2023-05-06 2023-05-01   Instagram
# 54   CMP-00055  Q1_Launch_CMP-00055 2023-09-01 2023-08-27  Google Ads
# 71   CMP-00072  Q1_Summer_CMP-00072 2023-02-01 2023-01-27       Email
#
#     impressions  clicks    spend  conversions  active campaign_tag
# 23        29693     995  1793.94        179.0   False           IN
# 54        18159     471   563.31         33.0   False           GO
# 71        66697    1340  2090.74          NaN    True           EM

# %%
wrong_end_dates = df['start_date'] > df['end_date']
df.loc[wrong_end_dates, 'end_date'] = df.loc[wrong_end_dates, 'start_date'] + pd.Timedelta(days=30)

# %% [markdown]
# ## String Parsing (Feature Extraction)

# %%
df['campaign_name'].head(10)
# Out:
# 0         Q4_Summer_CMP-00001
# 1         Q1_Launch_CMP-00002
# 2         Q3_Winter_CMP-00003
# 3    Q1_BlackFriday_CMP-00004
# 4         Q2_Winter_CMP-00005
# 5    Q4_BlackFriday_CMP-00006
# 6         Q3_Launch_CMP-00007
# 7         Q4_Launch_CMP-00008
# 8    Q4_BlackFriday_CMP-00009
# 9         Q2_Winter_CMP-00010
# Name: campaign_name, dtype: object

# %%
df['season'] = df['campaign_name'].str.extract(r'Q\d_([^_]+)_')
df['season']
# Out:
# 0            Summer
# 1            Launch
# 2            Winter
# 3       BlackFriday
# 4            Winter
#            ...
# 2015         Summer
# 2016         Summer
# 2017         Launch
# 2018         Winter
# 2019         Launch
# Name: season, Length: 2020, dtype: object
