# %% [markdown]
# # Support Vector Machine

# %% [markdown]
# - Support Vector Machines (SVM) are a set of supervised learning methods used for classification, regression and outliers detection.
# - SVM constructs a hyper-plane or set of hyper-planes in a high or infinite dimensional space, which can be used for classification, regression or other tasks.
# - In sklearn, we have three methods to implement SVM.

# %% [markdown]
# In Sklearn SVC can be implemented by 3 methods
# - SVC
# - NuSVC
# - LinearSVC

# %% [markdown]
# ### How to implement SVC (C-Support Vector Classification)?

# %%
from sklearn.svm import SVC
X, y = 0 #defining fake X and y so code snipped doesn't show error, Irl X and y should be matrix and label
svm_classifier = SVC()

svm_classifier.fit(X,y)

# %% [markdown]
# ### How to perform regularization in SVC classifier?
#
# `c` is Regularization parameter
# default = 1.0

# %% [markdown]
# ### How to specify kernel type to be used in the algorithm ?
#
# - linear
# - poly
# - rbf
# - sigmoid
# - precomputer

# %%
svc = SVC(kernal = 'rbf')
svc = SVC(kernel='poly', degree=2)

# %% [markdown]
# ### for rbf, sigmoid and poly
#
# gamma:
# - Scale
# - auto
# - float value
#
# value of gamma = 1/(no. of features * X.var())

# %% [markdown]
# ### How to view support vectors?
#
# After the classifier is fit on the training data, there are few attributes which reveal the details of support vectors.

# %%
svc = SVC()
clf = svc.fit(X,y)

clf.support_
clf.support_vectors_
clf.n_support_

# %% [markdown]
# ## NuSVC

# %% [markdown]
# Instead of `c`, `n` is used
# - v is an upper bound on the fraction of margin errors and and a lower bound of the fraction of support vectors.
# - Value of v = [0,1]
# - default = 0.5
#
#
# Other parameters are same

# %% [markdown]
# ## LinearSVC

# %% [markdown]
# ### How to provide penalty in LinearSVC classifier?
#
# - l1
# - l2

# %% [markdown]
# # Decision Tress

# %% [markdown]
# - classification : `sklearn.tree.DecisionTreeClassifier`
# - regression : `sklearn.tree.DecisionTreeRegression`

# %% [markdown]
# ### Tree Plot Visualisation
#
# `sklearn.tree.plot_tree`

# %% [markdown]
# ### Avoid Overfitting the tree
#
# - Pre-pruning: Uses hyper-parameter search like GridSearchCV for finding the best set of parameters.
# - Post-pruning: First grows trees without any constraints and then uses cost_complexity_pruning with max_depth and min_samples_split

# %% [markdown]
# # Voting, Bagging, and Random Forest

# %% [markdown]
# ## Voting Estimator

# %% [markdown]
# - Class: `sklearn.ensemble.VotingClassifier`
# - Class: `sklearn.ensemble.VotingRegressor`

# %% [markdown]
# ## Bagging

# %% [markdown]
# - Class: `sklearn.ensemble.BaggingClassifier`
# - Class: `sklearn.ensemble.BaggingRegressor`

# %% [markdown]
# ## Boosting

# %% [markdown]
# - AdaBoost
# - GradientBoosting
